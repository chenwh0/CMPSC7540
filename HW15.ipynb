# %% [markdown]
# Generative Adversarial Networks (GANs)
# ======
# This code implements a Deep Convolutional GAN (DCGAN), a GAN with only convolutional layers in the encoder and decoder.
#
# Based on [[this notebook]](https://github.com/smartgeometry-ucl/dl4g/blob/master/gan.ipynb).

# %%
import sys
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data_utils

import matplotlib.pyplot as plt

# %% [markdown]
# Parameter Settings
# -------------------

# %%
latent_dims = 10
num_epochs = 80
batch_size = 128
learning_rate = 2e-4
use_gpu = False

# %% [markdown]
# MNIST Data Loading
# -------------------
#
# MNIST images show digits from 0-9 in 28x28 grayscale images. The images are normalized and centerd around 0, which gives a slight performance boost during training. We create both a training set and a test set.

# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST

img_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = MNIST(root='./data/MNIST', download=True, train=True, transform=img_transform)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = MNIST(root='./data/MNIST', download=True, train=False, transform=img_transform)
test_dataloader = DataLoader(data_utils.Subset(test_dataset, range(500)), batch_size=batch_size, shuffle=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 42.3MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.23MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 10.9MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 4.51MB/s]

# %%
plt.imshow(train_dataset[2][0][0])
print(train_dataset[2][0].shape)
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# GAN Definition
# -----------------------
# We use a convolutional generator and discriminator, which generally gives better performance than fully connected versions that have the same number of parameters.
#
# Kernel size 4 is used to avoid biasing problems described here: https://distill.pub/2016/deconv-checkerboard/

# %%
class Generator(nn.Module):
    def __init__(self, d=16):
        super(Generator, self).__init__()
        self.deconv1 = nn.ConvTranspose2d(in_channels = 100, out_channels = d*2, kernel_size = 4)
        self.deconv1_bn = nn.BatchNorm2d(d*2)
        self.deconv2 = nn.ConvTranspose2d(in_channels = d*2, out_channels = d, kernel_size = 4, stride = 2, padding=1)
        self.deconv2_bn = nn.BatchNorm2d(d)
        self.deconv3 = nn.ConvTranspose2d(in_channels = d, out_channels = 1, kernel_size = 4, stride = 2, padding=1)

    def forward(self, input):
        x = F.relu(self.deconv1_bn(self.deconv1(input)))
        x = F.relu(self.deconv2_bn(self.deconv2(x)))
        x = torch.tanh(self.deconv3(x, output_size = (input.size()[0], 1, 28, 28)))

        return x

class Discriminator(nn.Module):
    def __init__(self, d=16):
        super(Discriminator, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = d, kernel_size = 4, stride = 2, padding = 1)
        self.conv1_bn = nn.BatchNorm2d(d)
        self.conv2 = nn.Conv2d(in_channels = d, out_channels = 1, kernel_size = 4, stride = 1, padding = 0)

        self.flatten = nn.Flatten()
        self.linear = nn.Linear(121, 1)

    def forward(self, input):
        x = F.leaky_relu(self.conv1(input), 0.2)
        x = self.flatten(self.conv2(x))
        x = torch.sigmoid(self.linear(x))

        return x

generator = Generator()
discriminator = Discriminator()

device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
generator = generator.to(device)
discriminator = discriminator.to(device)

num_params_gen = sum(p.numel() for p in generator.parameters() if p.requires_grad)
num_params_disc = sum(p.numel() for p in discriminator.parameters() if p.requires_grad)
print('Number of parameters for generator: %d and discriminator: %d' % (num_params_gen, num_params_disc))
# Out:
# Number of parameters for generator: 59793 and discriminator: 683

# %% [markdown]
# Train GAN
# --------

# %%
# GAN training can be unstable. In this case, the strong momentum
# for the gradient prevents convergence. One possible explanation is that the
# strong momentum does not allow the two players in the adversarial game to react
# to each other quickly enough. Decreasing beta1 (the exponential decay for the
# gradient moving average in [0,1], lower is faster decay) from the default 0.9
# to 0.5 allows for quicker reactions.
gen_optimizer = torch.optim.Adam(params=generator.parameters(), lr=learning_rate, betas=(0.5, 0.999))
disc_optimizer = torch.optim.Adam(params=discriminator.parameters(), lr=learning_rate, betas=(0.5, 0.999))

# set to training mode
generator.train()
discriminator.train()

gen_loss_avg = []
disc_loss_avg = []

print('Training ...')
for epoch in range(num_epochs):
    gen_loss_avg.append(0)
    disc_loss_avg.append(0)
    num_batches = 0

    for image_batch, _ in train_dataloader:

        # get dataset image and create real and fake labels for use in the loss
        image_batch = image_batch.to(device)
        label_real = torch.ones(image_batch.size(0), device=device)
        label_fake = torch.zeros(image_batch.size(0), device=device)

        # generate a batch of images from samples of the latent prior
        latent = torch.randn(image_batch.size(0), 100, 4, 4, device=device)
        fake_image_batch = generator(latent)

        # train discriminator to correctly classify real and fake
        # (detach the computation graph of the generator and the discriminator,
        # so that gradients are not backpropagated into the generator)
        real_pred = discriminator(image_batch).squeeze()
        fake_pred = discriminator(fake_image_batch.detach()).squeeze()
        disc_loss = 0.5 * (
            F.binary_cross_entropy(real_pred, label_real) +
            F.binary_cross_entropy(fake_pred, label_fake))

        disc_optimizer.zero_grad()
        disc_loss.backward()
        disc_optimizer.step()

        # train generator to output an image that is classified as real
        fake_pred = discriminator(fake_image_batch).squeeze()
        gen_loss = F.binary_cross_entropy(fake_pred, label_real)

        gen_optimizer.zero_grad()
        gen_loss.backward()
        gen_optimizer.step()

        gen_loss_avg[-1] += gen_loss.item()
        disc_loss_avg[-1] += disc_loss.item()
        num_batches += 1

    gen_loss_avg[-1] /= num_batches
    disc_loss_avg[-1] /= num_batches
    print('Epoch [%d / %d] average loss generator vs. discrim.: %f vs. %f' %
          (epoch+1, num_epochs, gen_loss_avg[-1], disc_loss_avg[-1]))
# Out:
# Training ...
# Epoch [1 / 80] average loss generator vs. discrim.: 0.875727 vs. 0.531336
# Epoch [2 / 80] average loss generator vs. discrim.: 1.007686 vs. 0.521504
# Epoch [3 / 80] average loss generator vs. discrim.: 0.990573 vs. 0.545729
# Epoch [4 / 80] average loss generator vs. discrim.: 0.875928 vs. 0.623308
# Epoch [5 / 80] average loss generator vs. discrim.: 0.875918 vs. 0.618200
# Epoch [6 / 80] average loss generator vs. discrim.: 0.877349 vs. 0.616106
# Epoch [7 / 80] average loss generator vs. discrim.: 0.903187 vs. 0.610634
# Epoch [8 / 80] average loss generator vs. discrim.: 0.901636 vs. 0.612983
# Epoch [9 / 80] average loss generator vs. discrim.: 0.902668 vs. 0.601860
# Epoch [10 / 80] average loss generator vs. discrim.: 0.933621 vs. 0.586200
# Epoch [11 / 80] average loss generator vs. discrim.: 0.931075 vs. 0.598547
# Epoch [12 / 80] average loss generator vs. discrim.: 0.930453 vs. 0.606616
# Epoch [13 / 80] average loss generator vs. discrim.: 0.926469 vs. 0.609242
# Epoch [14 / 80] average loss generator vs. discrim.: 0.895265 vs. 0.629727
# Epoch [15 / 80] average loss generator vs. discrim.: 0.874907 vs. 0.626469
# Epoch [16 / 80] average loss generator vs. discrim.: 0.869760 vs. 0.623020
# Epoch [17 / 80] average loss generator vs. discrim.: 0.893689 vs. 0.614117
# Epoch [18 / 80] average loss generator vs. discrim.: 0.863097 vs. 0.639636
# Epoch [19 / 80] average loss generator vs. discrim.: 0.860551 vs. 0.626580
# Epoch [20 / 80] average loss generator vs. discrim.: 0.887854 vs. 0.607346
# Epoch [21 / 80] average loss generator vs. discrim.: 0.895176 vs. 0.607912
# Epoch [22 / 80] average loss generator vs. discrim.: 0.902420 vs. 0.604470
# Epoch [23 / 80] average loss generator vs. discrim.: 0.915299 vs. 0.599445
# Epoch [24 / 80] average loss generator vs. discrim.: 0.922767 vs. 0.599841
# Epoch [25 / 80] average loss generator vs. discrim.: 0.930359 vs. 0.599416
# Epoch [26 / 80] average loss generator vs. discrim.: 0.938663 vs. 0.597861
# Epoch [27 / 80] average loss generator vs. discrim.: 0.949651 vs. 0.596690
# Epoch [28 / 80] average loss generator vs. discrim.: 0.953980 vs. 0.596298
# Epoch [29 / 80] average loss generator vs. discrim.: 0.960718 vs. 0.595566
# Epoch [30 / 80] average loss generator vs. discrim.: 0.969746 vs. 0.593680
# Epoch [31 / 80] average loss generator vs. discrim.: 0.975740 vs. 0.590172
# Epoch [32 / 80] average loss generator vs. discrim.: 0.985912 vs. 0.587578
# Epoch [33 / 80] average loss generator vs. discrim.: 0.994261 vs. 0.586611
# Epoch [34 / 80] average loss generator vs. discrim.: 0.995612 vs. 0.586083
# Epoch [35 / 80] average loss generator vs. discrim.: 1.000212 vs. 0.587434
# Epoch [36 / 80] average loss generator vs. discrim.: 1.010953 vs. 0.583629
# Epoch [37 / 80] average loss generator vs. discrim.: 1.013112 vs. 0.582589
# Epoch [38 / 80] average loss generator vs. discrim.: 1.021080 vs. 0.580264
# Epoch [39 / 80] average loss generator vs. discrim.: 1.026729 vs. 0.577368
# Epoch [40 / 80] average loss generator vs. discrim.: 1.037559 vs. 0.575826
# Epoch [41 / 80] average loss generator vs. discrim.: 1.042640 vs. 0.575092
# Epoch [42 / 80] average loss generator vs. discrim.: 1.048112 vs. 0.572825
# Epoch [43 / 80] average loss generator vs. discrim.: 1.053654 vs. 0.571449
# Epoch [44 / 80] average loss generator vs. discrim.: 1.059527 vs. 0.570449
# Epoch [45 / 80] average loss generator vs. discrim.: 1.064877 vs. 0.569468
# Epoch [46 / 80] average loss generator vs. discrim.: 1.070205 vs. 0.568443
# Epoch [47 / 80] average loss generator vs. discrim.: 1.078230 vs. 0.566851
# Epoch [48 / 80] average loss generator vs. discrim.: 1.081927 vs. 0.567084
# Epoch [49 / 80] average loss generator vs. discrim.: 1.090052 vs. 0.565684
# Epoch [50 / 80] average loss generator vs. discrim.: 1.090730 vs. 0.567402
# Epoch [51 / 80] average loss generator vs. discrim.: 1.091940 vs. 0.566473
# Epoch [52 / 80] average loss generator vs. discrim.: 1.091208 vs. 0.567737
# Epoch [53 / 80] average loss generator vs. discrim.: 1.092125 vs. 0.567800
# Epoch [54 / 80] average loss generator vs. discrim.: 1.093038 vs. 0.568569
# Epoch [55 / 80] average loss generator vs. discrim.: 1.097329 vs. 0.567761
# Epoch [56 / 80] average loss generator vs. discrim.: 1.097328 vs. 0.568889
# Epoch [57 / 80] average loss generator vs. discrim.: 1.094326 vs. 0.570235
# Epoch [58 / 80] average loss generator vs. discrim.: 1.091304 vs. 0.571017
# Epoch [59 / 80] average loss generator vs. discrim.: 1.091188 vs. 0.572318
# Epoch [60 / 80] average loss generator vs. discrim.: 1.086181 vs. 0.572897
# Epoch [61 / 80] average loss generator vs. discrim.: 1.088244 vs. 0.572290
# Epoch [62 / 80] average loss generator vs. discrim.: 1.088166 vs. 0.572534
# Epoch [63 / 80] average loss generator vs. discrim.: 1.088264 vs. 0.572628
# Epoch [64 / 80] average loss generator vs. discrim.: 1.083110 vs. 0.575572
# Epoch [65 / 80] average loss generator vs. discrim.: 1.084854 vs. 0.571869
# Epoch [66 / 80] average loss generator vs. discrim.: 1.084800 vs. 0.572385
# Epoch [67 / 80] average loss generator vs. discrim.: 1.078820 vs. 0.575050
# Epoch [68 / 80] average loss generator vs. discrim.: 1.078128 vs. 0.574514
# Epoch [69 / 80] average loss generator vs. discrim.: 1.074545 vs. 0.575981
# Epoch [70 / 80] average loss generator vs. discrim.: 1.079055 vs. 0.574178
# Epoch [71 / 80] average loss generator vs. discrim.: 1.080166 vs. 0.572928
# Epoch [72 / 80] average loss generator vs. discrim.: 1.078613 vs. 0.572240
# Epoch [73 / 80] average loss generator vs. discrim.: 1.076036 vs. 0.573073
# Epoch [74 / 80] average loss generator vs. discrim.: 1.081152 vs. 0.572815
# Epoch [75 / 80] average loss generator vs. discrim.: 1.081087 vs. 0.571282
# Epoch [76 / 80] average loss generator vs. discrim.: 1.085913 vs. 0.568949
# Epoch [77 / 80] average loss generator vs. discrim.: 1.085550 vs. 0.570750
# Epoch [78 / 80] average loss generator vs. discrim.: 1.083330 vs. 0.572328
# Epoch [79 / 80] average loss generator vs. discrim.: 1.084620 vs. 0.571563
# Epoch [80 / 80] average loss generator vs. discrim.: 1.083361 vs. 0.572048

# %% [markdown]
# Plot Training Curves
# --------------------

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure()
plt.plot(gen_loss_avg, label='generator')
plt.plot(disc_loss_avg, label='discriminator')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Sample Latent Vector from Prior (GAN as Generator)
# -------------------------------------------------
#
# GANs usually generate higher-quality results than VAEs or plain Autoencoders, since the distribution of generated digits is more focused on the modes of the real data distribution (see tutorial slides). However, they are harder to train and don't have an encoder, which means the inference of a latent code from a given image is not possible.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

generator.eval()

def to_img(x):
    x = 0.5 * (x + 1)
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

with torch.no_grad():

    # sample latent vectors from the standard normal distribution
    latent = torch.randn(image_batch.size(0), 100, 4, 4, device=device)
    fake_image_batch = generator(latent)
    fake_image_batch = fake_image_batch.cpu()

    fig, ax = plt.subplots(figsize=(8, 8))
    show_image(torchvision.utils.make_grid(fake_image_batch.data[:100],10,5))
    plt.show()

# %% [markdown]
# Interpolate in Latent Space
# ----------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

generator.eval()

def interpolation(lambda1, model, latent_1, latent_2):

    with torch.no_grad():

        # interpolation of the two latent vectors
        inter_latent = lambda1 * latent_1 + (1- lambda1) * latent_2

        # reconstruct interpolated image
        inter_latent = inter_latent.to(device)
        inter_image = model(inter_latent)
        inter_image = inter_image.cpu()

        return inter_image

# sample two latent vectors from the standard normal distribution
latent_1 = torch.randn(1, 100, 4, 4, device=device)
latent_2 = torch.randn(1, 100, 4, 4, device=device)

# interpolation lambdas
lambda_range=np.linspace(0, 1, 10)

fig, axs = plt.subplots(2,5, figsize=(15, 6))
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

for ind,l in enumerate(lambda_range):
    inter_image=interpolation(float(l), generator, latent_1, latent_2)

    inter_image = to_img(inter_image)

    image = inter_image.numpy()

    axs[ind].imshow(image[0,0,:,:], cmap='gray')
    axs[ind].set_title('lambda_val='+str(round(l,1)))
plt.show()

# %% [markdown]
# ## **My results**
# My results were okay, some of the numbers can be recognized (most prominent/obvious digits being 0s, 9s, and 8s). I don't think increasing the number of epochs further will improve my model because as seen in the loss function graph, the loss starts to increase again after ~20 epochs. If I had more training time/computing power I will improve my model by adding more layers so that more granular details can be captured and generated by my model. We can see from the 2nd row of interpolation images that the model is slowly learning the curve-like shape that could be found in digits like 9, 4, 8, 3.
#
# I also trained the same model with only 20 epochs and below is the result
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# the model could've been overfitting when it was given an 80 epoch time to train
