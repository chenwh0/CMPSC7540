# %% [markdown]
# This is notebook gives a quick overview of this WaveNet implementation, i.e. creating the model and the data set, training the model and generating samples from it.

# %%
#!git clone https://github.com/Vichoko/pytorch-wavenet.git
import sys
sys.path.append("pytorch-wavenet")
import torch
from wavenet_model import *
from audio_data import WavenetDataset
from wavenet_training import *
from model_logging import *

# %%
import os
os.makedirs("snapshots", exist_ok=True)

# %%
# !zip -r pytorch-wavenet.zip /content/pytorch-wavenet/
# Out:
# updating: content/pytorch-wavenet/ (stored 0%)
# updating: content/pytorch-wavenet/optimizers.py (deflated 65%)
# updating: content/pytorch-wavenet/train_samples/ (stored 0%)
# updating: content/pytorch-wavenet/train_samples/.DS_Store (deflated 93%)
# updating: content/pytorch-wavenet/train_samples/bach_chaconne/ (stored 0%)
# updating: content/pytorch-wavenet/train_samples/bach_chaconne/.DS_Store (deflated 97%)
# updating: content/pytorch-wavenet/train_samples/bach_chaconne/dataset.npz (deflated 14%)
# updating: content/pytorch-wavenet/wavenet_modules.py (deflated 64%)
# updating: content/pytorch-wavenet/.ipynb_checkpoints/ (stored 0%)
# updating: content/pytorch-wavenet/.ipynb_checkpoints/WaveNet_demo-checkpoint.ipynb (deflated 72%)
# updating: content/pytorch-wavenet/.ipynb_checkpoints/demo-checkpoint.ipynb (deflated 80%)
# updating: content/pytorch-wavenet/.ipynb_checkpoints/Generated_Samples-checkpoint.ipynb (deflated 25%)
# updating: content/pytorch-wavenet/WaveNet_demo.ipynb (deflated 72%)
# updating: content/pytorch-wavenet/snapshots/ (stored 0%)
# updating: content/pytorch-wavenet/test_script.py (deflated 68%)
# updating: content/pytorch-wavenet/README.md (deflated 46%)
# updating: content/pytorch-wavenet/.DS_Store (deflated 91%)
# updating: content/pytorch-wavenet/train_script.py (deflated 69%)
# updating: content/pytorch-wavenet/wavenet_training.py (deflated 71%)
# updating: content/pytorch-wavenet/.gitignore (deflated 51%)
# updating: content/pytorch-wavenet/LICENSE (deflated 41%)
# updating: content/pytorch-wavenet/wavenet_model.py (deflated 77%)
# updating: content/pytorch-wavenet/model_logging.py (deflated 73%)
# updating: content/pytorch-wavenet/.idea/ (stored 0%)
# updating: content/pytorch-wavenet/.idea/modules.xml (deflated 36%)
# updating: content/pytorch-wavenet/.idea/WaveNet.iml (deflated 23%)
# updating: content/pytorch-wavenet/.idea/workspace.xml (deflated 88%)
# updating: content/pytorch-wavenet/generate_script.py (deflated 60%)
# updating: content/pytorch-wavenet/Generated_Samples.ipynb (deflated 25%)
# updating: content/pytorch-wavenet/generated_samples/ (stored 0%)
# updating: content/pytorch-wavenet/generated_samples/.DS_Store (deflated 97%)
# updating: content/pytorch-wavenet/generated_samples/chaconne_temp_0,5.mp3 (deflated 1%)
# updating: content/pytorch-wavenet/generated_samples/chaconne_temp_0,8.mp3 (deflated 1%)
# updating: content/pytorch-wavenet/generated_samples/chaconne_temp_1,0.mp3 (deflated 1%)
# updating: content/pytorch-wavenet/__pycache__/ (stored 0%)
# updating: content/pytorch-wavenet/__pycache__/model_logging.cpython-311.pyc (deflated 57%)
# updating: content/pytorch-wavenet/__pycache__/audio_data.cpython-311.pyc (deflated 51%)
# updating: content/pytorch-wavenet/__pycache__/wavenet_modules.cpython-35.pyc (deflated 52%)
# updating: content/pytorch-wavenet/__pycache__/wavenet_training.cpython-311.pyc (deflated 49%)
# updating: content/pytorch-wavenet/__pycache__/wavenet_model.cpython-35.pyc (deflated 52%)
# updating: content/pytorch-wavenet/__pycache__/wavenet_training.cpython-35.pyc (deflated 46%)
# updating: content/pytorch-wavenet/__pycache__/wavenet_model.cpython-311.pyc (deflated 55%)
# updating: content/pytorch-wavenet/__pycache__/wavenet_modules.cpython-311.pyc (deflated 50%)
# updating: content/pytorch-wavenet/audio_data.py (deflated 71%)
# updating: content/pytorch-wavenet/demo.ipynb (deflated 55%)
# updating: content/pytorch-wavenet/notebooks/ (stored 0%)
# updating: content/pytorch-wavenet/notebooks/audio_normalizer.maxpat (deflated 87%)
# updating: content/pytorch-wavenet/notebooks/SELU.ggb (deflated 4%)
# updating: content/pytorch-wavenet/notebooks/tests.ipynb (deflated 82%)
# updating: content/pytorch-wavenet/notebooks/WaveNet2Train.ipynb (deflated 85%)
# updating: content/pytorch-wavenet/notebooks/WavenetTrain.ipynb (deflated 53%)
# updating: content/pytorch-wavenet/notebooks/WavenetGenerate.ipynb (deflated 44%)
# updating: content/pytorch-wavenet/notebooks/WaveNet2Generate.ipynb (deflated 44%)
# updating: content/pytorch-wavenet/notebooks/Dilation.ipynb (deflated 81%)
# updating: content/pytorch-wavenet/visualize.py (deflated 60%)
# updating: content/pytorch-wavenet/.git/ (stored 0%)
# updating: content/pytorch-wavenet/.git/refs/ (stored 0%)
# updating: content/pytorch-wavenet/.git/refs/remotes/ (stored 0%)
# updating: content/pytorch-wavenet/.git/refs/remotes/origin/ (stored 0%)
# updating: content/pytorch-wavenet/.git/refs/remotes/origin/HEAD (stored 0%)
# updating: content/pytorch-wavenet/.git/refs/heads/ (stored 0%)
# updating: content/pytorch-wavenet/.git/refs/heads/master (stored 0%)
# updating: content/pytorch-wavenet/.git/refs/tags/ (stored 0%)
# updating: content/pytorch-wavenet/.git/objects/ (stored 0%)
# updating: content/pytorch-wavenet/.git/objects/pack/ (stored 0%)
# updating: content/pytorch-wavenet/.git/objects/pack/pack-fefba282c2cfaadd59a56111069af9c77b546454.pack
#
#
# zip error: Interrupted (aborting)

# %% [markdown]
# ## Model
# This is an implementation of WaveNet as it was described in the original paper (https://arxiv.org/abs/1609.03499). Each layer looks like this:
#
# ```
#             |----------------------------------------|      *residual*
#             |                                        |
#             |    |-- conv -- tanh --|                |
#  -> dilate -|----|                  * ----|-- 1x1 -- + -->  *input*
#                  |-- conv -- sigm --|     |
#                                          1x1
#                                           |
#  ---------------------------------------> + ------------->  *skip*
# ```
#
# Each layer dilates the input by a factor of two. After each block the dilation is reset and start from one. You can define the number of layers in each block (``layers``) and the number of blocks (``blocks``). The blocks are followed by two 1x1 convolutions and a softmax output function.
# Because of the dilation operation, the independent output for multiple successive samples can be calculated efficiently. With ``output_length``, you can define the number these outputs. Empirically, it seems that a large number of skip channels is required.

# %%
# initialize cuda option
dtype = torch.FloatTensor # data type
ltype = torch.LongTensor # label type

use_cuda = torch.cuda.is_available()
if use_cuda:
    print('use gpu')
    dtype = torch.cuda.FloatTensor
    ltype = torch.cuda.LongTensor
# Out:
# use gpu

# %%
"""model = WaveNetModel(layers=2,
                     blocks=2,
                     dilation_channels=2,
                     residual_channels=2,
                     skip_channels=2,
                     end_channels=2,
                     output_length=16,
                     dtype=dtype,
                     bias=True,
                     )
                     """
# model = load_latest_model_from('snapshots', use_cuda=use_cuda)

print('model: ', model)
print('receptive field: ', model.receptive_field)
print('parameter count: ', model.parameter_count())
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-7-d4234be3f8b9> in <cell line: 0>()
#      21 # Now load the model
#      22 checkpoint_path = '/content/snapshots/chaconne_model_2025-04-16_23-22-34'  # Replace with actual path to the checkpoint
# ---> 23 checkpoint = torch.load(checkpoint_path, map_location='cuda' if use_cuda else 'cpu', weights_only=True)
#      24
#      25 # Initialize your model
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1468                         )
#    1469                     except pickle.UnpicklingError as e:
# -> 1470                         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1471                 return _load(
#    1472                     opened_zipfile,
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL torch.nn.modules.container.ModuleList was not an allowed global by default. Please use `torch.serialization.add_safe_globals([ModuleList])` or the `torch.serialization.safe_globals([ModuleList])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %% [markdown]
# ## Data Set
# To create the data set, you have to specify a path to a data set file. If this file already exists it will be used, if not it will be generated. If you want to generate the data set file (a ``.npz`` file), you have to specify the directory (``file_location``) in which all the audio files you want to use are located. The attribute ``target_length`` specifies the number of successive samples are used as a target and corresponds to the output length of the model. The ``item_length`` defines the number of samples in each item of the dataset and should always be ``model.receptive_field + model.output_length - 1``.
#
# ```
#           |----receptive_field----|
#                                 |--output_length--|
# example:  | | | | | | | | | | | | | | | | | | | | |
# target:                           | | | | | | | | | |
# ```
# To create a test set, you should define a ``test_stride``. Then each ``test_stride``th item will be assigned to the test set.

# %%
data = WavenetDataset(dataset_file='pytorch-wavenet/train_samples/bach_chaconne/dataset.npz',
                      item_length=model.receptive_field + model.output_length - 1,
                      target_length=model.output_length,
                      file_location='train_samples/bach_chaconne',
                      test_stride=500)
print('the dataset has ' + str(len(data)) + ' items')
# Out:
# one hot input
# the dataset has 598467 items

# %% [markdown]
# ## Training and Logging
# This implementation supports logging with TensorBoard (you need to have TensorFlow installed). You can even generate audio samples from the current snapshot of the model during training. This will happen in a background thread on the cpu, so it will not interfere with the actual training but will be rather slow. If you don't have TensorFlow, you can use the standard logger that will print out to the console.
# The trainer uses Adam as default optimizer.

# %%
def generate_and_log_samples(step):
    sample_length=32000
    gen_model = load_latest_model_from('snapshots', use_cuda=False)
    print("start generating...")
    samples = generate_audio(gen_model,
                             length=sample_length,
                             temperatures=[0.5])
    tf_samples = tf.convert_to_tensor(samples, dtype=tf.float32)
    logger.audio_summary('temperature_0.5', tf_samples, step, sr=16000)

    samples = generate_audio(gen_model,
                             length=sample_length,
                             temperatures=[1.])
    tf_samples = tf.convert_to_tensor(samples, dtype=tf.float32)
    logger.audio_summary('temperature_1.0', tf_samples, step, sr=16000)
    print("audio clips generated")

"""
logger = TensorboardLogger(log_interval=200,
                           validation_interval=400,
                           generate_interval=1000,
                           generate_function=generate_and_log_samples,
                           log_dir="logs/chaconne_model")
"""
logger = Logger(log_interval=200,
                validation_interval=400,
                generate_interval=1000)
# 6000

# %%
model.cuda()
trainer = WavenetTrainer(model=model,
                         dataset=data,
                         lr=0.01,
                         snapshot_path='snapshots',
                         snapshot_name='chaconne_model',
                         snapshot_interval=1000,
                         logger=logger,
                         dtype=dtype,
                         ltype=ltype)

print('start training...')
trainer.train(batch_size=6,
              epochs=1)
# Out:
# start training...
# epoch 0
# one training step does take approximately 0.06068881273269654 seconds)
# loss at step 200: tensor(5.3096, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 400: tensor(5.1402, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.277937476634979
# validation accuracy: 0.9539199332777314%
# loss at step 600: tensor(5.1500, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 800: tensor(5.1469, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.276752121448517
# validation accuracy: 0.7662635529608007%
# loss at step 1000: tensor(5.1407, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 1200: tensor(5.1367, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.276032621860504
# validation accuracy: 0.8288156797331109%
# loss at step 1400: tensor(5.1416, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 1600: tensor(5.1415, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.2852328848838805
# validation accuracy: 0.9539199332777314%
# loss at step 1800: tensor(5.1345, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 2000: tensor(5.1357, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.28585426568985
# validation accuracy: 0.7506255212677231%
# loss at step 2200: tensor(5.1421, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 2400: tensor(5.1219, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.309701354503631
# validation accuracy: 0.7037114261884904%
# loss at step 2600: tensor(5.1364, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 2800: tensor(5.1437, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.2818592834472655
# validation accuracy: 0.6776480400333611%
# loss at step 3000: tensor(5.1418, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 3200: tensor(5.1196, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.281453609466553
# validation accuracy: 0.432652210175146%
# loss at step 3400: tensor(5.1361, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 3600: tensor(5.1494, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.2729293251037594
# validation accuracy: 0.6411592994161801%
# loss at step 3800: tensor(5.1519, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 4000: tensor(5.1359, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.2675538563728335
# validation accuracy: 0.9174311926605505%
# loss at step 4200: tensor(5.1346, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 4400: tensor(5.1512, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.257834622859955
# validation accuracy: 0.7558381984987489%
# loss at step 4600: tensor(5.1343, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 4800: tensor(5.1498, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.243899602890014
# validation accuracy: 0.5994578815679733%
# loss at step 5000: tensor(5.1399, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 5200: tensor(5.1337, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.273685863018036
# validation accuracy: 0.8079649708090075%
# loss at step 5400: tensor(5.1378, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 5600: tensor(5.1436, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.280857212543488
# validation accuracy: 0.9174311926605505%
# loss at step 5800: tensor(5.1389, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 6000: tensor(5.1404, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.2575831842422485
# validation accuracy: 0.7193494578815679%
# loss at step 6200: tensor(5.1532, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 6400: tensor(5.1380, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.276793043613434
# validation accuracy: 0.6567973311092578%
# loss at step 6600: tensor(5.1488, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 6800: tensor(5.1363, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.282572610378265
# validation accuracy: 1.0008340283569641%
# loss at step 7000: tensor(5.1438, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 7200: tensor(5.1471, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.266982140541077
# validation accuracy: 0.7610508757297748%
# loss at step 7400: tensor(5.1306, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 7600: tensor(5.1445, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.276511380672455
# validation accuracy: 0.6776480400333611%
# loss at step 7800: tensor(5.1386, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 8000: tensor(5.1372, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.2611358571052556
# validation accuracy: 0.8392410341951626%
# loss at step 8200: tensor(5.1325, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 8400: tensor(5.1489, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.254691770076752
# validation accuracy: 0.35967472894078395%
# loss at step 8600: tensor(5.1433, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 8800: tensor(5.1400, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.288401846885681
# validation accuracy: 0.8496663886572143%
# loss at step 9000: tensor(5.1402, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 9200: tensor(5.1370, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.270907971858978
# validation accuracy: 0.8809424520433694%
# loss at step 9400: tensor(5.1478, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 9600: tensor(5.1504, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.271821789741516
# validation accuracy: 0.8809424520433694%
# loss at step 9800: tensor(5.1385, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 10000: tensor(5.1311, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.268834276199341
# validation accuracy: 0.8809424520433694%
# loss at step 10200: tensor(5.1424, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 10400: tensor(5.1287, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.278934071063995
# validation accuracy: 0.9226438698915764%
# loss at step 10600: tensor(5.1288, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 10800: tensor(5.1458, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.275925550460816
# validation accuracy: 0.7558381984987489%
# loss at step 11000: tensor(5.1393, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 11200: tensor(5.1383, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.269521565437317
# validation accuracy: 0.7610508757297748%
# loss at step 11400: tensor(5.1298, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 11600: tensor(5.1575, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.273052020072937
# validation accuracy: 0.6359466221851543%
# loss at step 11800: tensor(5.1396, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 12000: tensor(5.1286, device='cuda:0', grad_fn=<DivBackward0>)
# validation loss: 5.278295254707336
# validation accuracy: 0.7819015846538782%
# loss at step 12200: tensor(5.1436, device='cuda:0', grad_fn=<DivBackward0>)
# loss at step 12400: tensor(5.1392, device='cuda:0', grad_fn=<DivBackward0>)

# %% [markdown]
# ## Generating
# This model has the Fast Wavenet Generation Algorithm (https://arxiv.org/abs/1611.09482) implemented. This might run faster on the cpu. You can give some starting data (of at least the length of receptive field) or let the model generate from zero. In my experience, a temperature between 0.5 and 1.0 yields the best results, but this may depend on the data set.

# %%
# Check the length of the dataset
dataset_length = len(data)
print(f"Dataset length: {dataset_length}")

# Ensure the index is within the dataset bounds
index = min(250000, dataset_length - 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-df2aa9f44ccc> in <cell line: 0>()
#       1 # Check the length of the dataset
# ----> 2 dataset_length = len(data)
#       3 print(f"Dataset length: {dataset_length}")
#       4
#       5 # Ensure the index is within the dataset bounds
#
# NameError: name 'data' is not defined

# %%
start_data = data[index][0] # use start data from the data set
start_data = torch.max(start_data, 0)[1] # convert one hot vectors to integers
if use_cuda:
    start_data = start_data.cuda()
def prog_callback(step, total_steps):
    print(str(100 * step // total_steps) + "% generated")

generated = model.generate_fast(num_samples=160000,
                                 first_samples=start_data,
                                 progress_callback=prog_callback,
                                 progress_interval=1000,
                                 temperature=1.0,
                                 regularize=0.)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-c77b20af3a6c> in <cell line: 0>()
#       6     print(str(100 * step // total_steps) + "% generated")
#       7
# ----> 8 generated = model.generate_fast(num_samples=160000,
#       9                                  first_samples=start_data,
#      10                                  progress_callback=prog_callback,
#
# /content/pytorch-wavenet/wavenet_model.py in generate_fast(self, num_samples, first_samples, temperature, regularize, progress_callback, progress_interval)
#     258     queue = []
#     259     for i in range(len(self.dilations)):
# --> 260         queue.append(torch.zeros(self.dilation_channels,
#     261                                  self.dilations[i],
#     262                                  1).to(device))
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument index in method wrapper_CUDA_scatter__value)

# %%
import IPython.display as ipd

ipd.Audio(generated, rate=16000)

# %%
from IPython.display import Audio

# Specify the path to the uploaded file
file_path = 'raw_audio.wav'  # Replace with the correct path

# Play the audio
Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **My comments**
# Even though I trained my model for 1 hour, I was unable to get the model to output audio that sounded similar to music in the end. The quality of my generated sample was not very good, the audio generated sounded like static noise.
#
# Potential improvements will be to train the model for higher epochs so that the model has more opprutunities to adjust its weights and reduce error. Another way to improve the quality of the generated output is to increase the number of layers, dialation channels, residual channels as this would all allow the model to learn more complex features from the training data, however this would mean a long training time so that was not implemented here
